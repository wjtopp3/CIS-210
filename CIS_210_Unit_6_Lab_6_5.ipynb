# %% [markdown]
# <a href="https://colab.research.google.com/github/wjtopp3/CIS-210/blob/main/CIS_210_Unit_6_Lab_6_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The homes.csv dataset contains information for houses sold in King County, Washington in 2014. Features include sales price, square footage, number of bedrooms and bathrooms, and the number of floors. The priceFloor dataframe contains the features Price and Floor. The school dataframe contains the feature School.
#
# - Define a standardization scaler to transform values and apply the scaler to the priceFloor data.
#
# - Define a normalization scaler to transform values and apply the scaler to the priceFloor data.
#
# - Define an ordinal encoder using OrdinalEncoder(). Apply the ordinal encoder to the school data.
#
# = Add the encoded labels as a column labeled encoding to the school dataframe.
#
# - Create and fit a discretizer with equal weights and 3 bins to the Floor feature from the priceFloor data.
#
# - Reshape the feature to an array with dimensions (76,1).
#
# -------------------------
#
# The output should be:
#
# Standardized data:
#         Price     Floor
# 0   1.071227 -2.504029
# 1   0.220305  0.111864
# 2   0.902711  0.367766
# 3   0.654108 -1.466202
# 4  -0.013282 -0.437853
# ..       ...       ...
# 71 -1.448170  0.216120
# 72 -1.681757 -0.523154
# 73 -0.280238 -0.807490
# 74  0.153566  0.272988
# 75 -0.555536 -0.390463
#
# [76 rows x 2 columns]
# Normalized data:
#         Price     Floor
# 0   0.660441  0.001374
# 1   0.487267  0.380495
# 2   0.626146  0.417582
# 3   0.575552  0.151786
# 4   0.439728  0.300824
# ..       ...       ...
# 71  0.147708  0.395604
# 72  0.100170  0.288462
# 73  0.385399  0.247253
# 74  0.473684  0.403846
# 75  0.329372  0.307692
#
# [76 rows x 2 columns]
# Encoded data:
#       School  encoding
# 0     Adams       0.0
# 1    Parker       4.0
# 2   Redwood       5.0
# 3     Crest       1.0
# 4     Crest       1.0
# ..      ...       ...
# 71  Redwood       5.0
# 72   Parker       4.0
# 73  Redwood       5.0
# 74  Redwood       5.0
# 75   Edison       2.0
#
# [76 rows x 2 columns]
# Bin widths:
#  [1.44       1.92533333 2.41066667 2.896     ]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import KBinsDiscretizer

homes = pd.read_csv('homes.csv')
priceFloor = homes[['Price', 'Floor']]
school = homes[['School']]

# Define a standardization scaler to transform values
# Your code here

# Apply scaler to the priceFloor data
scaled = # Your code here

homes_standardized = pd.DataFrame(scaled, columns=['Price','Floor'])
print('Standardized data: \n', homes_standardized)

# Define a normalization scaler to transform values
# Your code here

# Apply scaler to the priceFloor data
normalized = # Your code here

homes_normalized = pd.DataFrame(normalized, columns=['Price','Floor'])
print('Normalized data: \n', homes_normalized)

# Define the OrdinalEncoder() function
ordinal_encoder = OrdinalEncoder()
# Create a dataframe of the ordinal encoder function fit to the school data, with the column labeled encoding
# Your code here

# Join the new column to the school data
school_encoded = # Your code here

print('Encoded data: \n', school_encoded)

# Create a discretizer with equal weights and 3 bins
discretizer_eqwidth = # Your code here

# Fit the discretizer to the Floor feature from the priceFloor data.
# Reshape the feature to an array with dimensions (76,1).
# Your code here

print('Bin widths: \n', discretizer_eqwidth.bin_edges_[0])

# %%
# zyBooks solution
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import KBinsDiscretizer

homes = pd.read_csv('homes.csv')
priceFloor = homes[['Price', 'Floor']]
school = homes[['School']]

# Define a standardization scaler to transform values
standard_scaler = StandardScaler()

# Apply scaler to the priceFloor data
scaled = standard_scaler.fit_transform(priceFloor)

homes_standardized = pd.DataFrame(scaled, columns=['Price','Floor'])
print('Standardized data: \n', homes_standardized)

# Define a normalization scaler to transform values
minmax_scaler = MinMaxScaler()

# Apply scaler to the priceFloor data
normalized = minmax_scaler.fit_transform(priceFloor)

homes_normalized = pd.DataFrame(normalized, columns=['Price','Floor'])
print('Normalized data: \n', homes_normalized)

# Define the OrdinalEncoder() function
ordinal_encoder = OrdinalEncoder()
# Create a dataframe of the ordinal encoder function fit to the school data, with the column labeled encoding
labels = pd.DataFrame(ordinal_encoder.fit_transform(school[['School']]),columns=['encoding'])
# Join the new column to the school data
school_encoded = school.join(labels)

print('Encoded data: \n', school_encoded)

# Create and fit a discretizer with equal weights and 3 bins to the Floor feature from the priceFloor data
discretizer_eqwidth = KBinsDiscretizer(n_bins=3, strategy='uniform')
discretizer_eqwidth.fit(np.reshape(priceFloor[['Floor']],(76,1)))

print('Bin widths: \n', discretizer_eqwidth.bin_edges_[0])

# %%
# Claude's solution
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder, KBinsDiscretizer

# Load the dataset
homes = pd.read_csv('homes.csv')

# Create priceFloor dataframe
priceFloor = homes[['Price', 'Floor']].copy()

# Create school dataframe
school = homes[['School']].copy()

# 1. Standardization (Z-score normalization)
standard_scaler = StandardScaler()
standardized_data = standard_scaler.fit_transform(priceFloor)
standardized_df = pd.DataFrame(standardized_data, columns=['Price', 'Floor'])

print("Standardized data: ")
print(standardized_df)

# 2. Normalization (Min-Max scaling)
normalizer = MinMaxScaler()
normalized_data = normalizer.fit_transform(priceFloor)
normalized_df = pd.DataFrame(normalized_data, columns=['Price', 'Floor'])

print("Normalized data: ")
print(normalized_df)

# 3. Ordinal Encoding
ordinal_encoder = OrdinalEncoder()
encoded_labels = ordinal_encoder.fit_transform(school)
school['encoding'] = encoded_labels

print("Encoded data: ")
print(school)

# 4. Discretization with KBinsDiscretizer
# Reshape Floor feature to (76, 1)
floor_reshaped = priceFloor['Floor'].values.reshape(-1, 1)

# Create and fit discretizer with equal width (uniform) and 3 bins
discretizer = KBinsDiscretizer(n_bins=3, encode='ordinal', strategy='uniform')
discretizer.fit(floor_reshaped)

# Get bin edges (widths)
bin_edges = discretizer.bin_edges_[0]

print("Bin widths: ")
print(bin_edges)
